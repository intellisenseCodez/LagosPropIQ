# %% [markdown]
# # Data Extraction from Private Property.ng Website

# %%
# Importing Libraries

import requests
from bs4 import BeautifulSoup

# %%
# Error handling function while loading the site and
# Defining the Header for using User-Agent approach to have access to the site info

URL ="https://privateproperty.ng/property-for-rent"

HEADER = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36"
}

def make_connection(url):
    try:
        response = requests.get(url, headers=HEADER)
        if response.status_code == 200:
            soup_content = BeautifulSoup(response.content, 'html.parser')
            return soup_content
        else:
            print(f"Resources Not available! Status Code {response.staus_code}")
    except Exception as e:
        print(f"An Error occurs. Message: {e}")

# %%
content = make_connection(url = URL)

# %%
content
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Find Property For Rent in Nigeria (7,155 Listed) | Private Property Nigeria</title><!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="app-id=1625495384" name="apple-itunes-app"/>
# <meta content="app-id=ng.com.privateproperty.app" name="google-play-app"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://privateproperty.ng/assets/manifest.json" rel="manifest"/>
# <link href="https://privateproperty.ng/assets/launcher-icon-60.png" rel="apple-touch-icon"/>
# <link href="https://privateproperty.ng/assets/launcher-icon-76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://privateproperty.ng/assets/launcher-icon-120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://privateproperty.ng/assets/launcher-icon-152.png" rel="apple-touch-icon" sizes="152x152"/>
# ...

# %%
property_info = content.find("div", class_= "similar-listings-item")

# %%
property_info
# Out:
# <div class="similar-listings-item sponsored-listing">
# <div class="row">
# <div class="col-md-4">
# <div class="similar-listings-image sponsored">
# <a href="/listings/3-bedroom-shared-apartment-for-rent-lekki-phase-1-lagos-4PDCBZ">
# <div class="similarSlider">
# <div>
# <img alt="3 bedroom Shared Apartment For Rent Lekki Phase 1 Lagos" data-src="https://images.privateproperty.com.ng/medium/3-units-of-well-maintained-3-bedroom-apartments-in-q1Qn3bUuPvuz8HsZIWe2.jpeg" src="..." title="3 bedroom Shared Apartment For Rent Lekki Phase 1 Lagos"/>
# </div>
# </div></a>
# <p class="total-images"><img alt="" src="/assets/static/main/images/e9507531278bcbef08973aabd2704aff-icon16.png"/> 7</p>
# </div>
# </div><!-- -->
# <div class="col-md-4">
# <div class="similar-listings-info">
# <h2><a href="/listings/3-bedroom-shared-apartment-for-rent-lekki-phase-1-lagos-4PDCBZ">3 Units Of Well Maintained 3 Bedroom Apartments In A Serviced Estate</a></h2>
# <h3>3 BEDROOM SHARED APARTMENT For Rent</h3>
# ...

# %%
# listing title
property_info.find("div", class_= "similar-listings-info").find('h2').get_text()
# Out:
# '3 Units Of Well Maintained 3 Bedroom Apartments In A Serviced Estate'

# %%
# property title
property_info.find("div", class_= "similar-listings-info").find('h3').get_text()
# Out:
# '3 BEDROOM SHARED APARTMENT For Rent'

# %%
# property location
property_info.find("div", class_= "similar-listings-info").find('p').get_text()
# Out:
# '\n\n\n Lekki Phase 1 Lagos'

# %%
# property price
property_info.find("div", class_= "similar-listings-price").find('h4').get_text()
# Out:
# '₦ 15,000,000/year'

# %%
# property price currency
property_info.find("div", class_= "similar-listings-price").find('span').get_text()
# Out:
# '₦'

# %%
# property last updated
property_info.find("div", class_= "media-body").find('h5').get_text()
# Out:
# 'Updated Today'

# %%
# property benefit- bathroom
property_info.find("ul", class_= "property-benefit").find('li').get_text()
# Out:
# '\n\n\n 3'

# %%
# property benefit- toilet
property_info.find("ul", class_= "property-benefit").find('li').find('svg').get_text()
# Out:
# '\n\n'

# %%
# property benefit- bedroom
property_info.find("ul", class_= "property-benefit").find('li').get_text()
# Out:
# '\n\n\n 3'

# %%
# Agent link
property_info.find("div", class_= "media").find('a').get('href')
# Out:
# '/estate-agents/casaprimeproperties'

# %%
# property contact
property_info.find("div", class_= "similar-listing-contact").find('a').get_text()
# Out:
# '\n\n\n CALL '

# %%
# Agent Name
pryeds = property_info.find("div", class_= "media").find('img').get('alt')
print(pryeds)
# Out:
# Casa Prime Properties

# %%
# property image-url
property_info.find("div", class_= "col-md-4").find('p')
# Out:
# <p class="total-images"><img alt="" src="/assets/static/main/images/e9507531278bcbef08973aabd2704aff-icon16.png"/> 7</p>
