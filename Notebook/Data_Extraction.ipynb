# %% [markdown]
# # Data Extraction from Private Property.ng Website

# %%
# Importing Libraries

import requests
from bs4 import BeautifulSoup 
import re

# importing the library to scrap image
import os
from urllib.parse import urljoin

# import library for date
from datetime import datetime, timedelta

# %%
# Error handling function while loading the site and
# Defining the Header for using User-Agent approach to have access to the site info

HEADER = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36"
}


def make_connection(url):
    """ Make a request to http url
    and return a beautiful soup object"""
    try:
        response = requests.get(url, headers=HEADER)
        if response.status_code == 200:
            soup_content = BeautifulSoup(response.content, 'html.parser')
            return soup_content
        else:
            print(f"Resources Not available! Status Code {response.status_code}")
    except Exception as e:
        print(f"An Error occurs. Message: {e}")

# Extract amenities 
def property_amenities(property_info):
    amenities = {"bedrooms": "N/A", "bathrooms": "N/A", "toilets": "N/A"}
    
    amenity_div = property_info.find("ul", class_="property-benefit")
    if not amenity_div:
        return amenities
    
    amenity_tags = amenity_div.find_all("li")
    
    # Use index positions
    if len(amenity_tags) >= 1:
        text = amenity_tags[0].get_text(strip=True)
        amenities["bedrooms"] = int(text) if text.isdigit() else "N/A"
    if len(amenity_tags) >= 2:
        text = amenity_tags[1].get_text(strip=True)
        amenities["bathrooms"] = int(text) if text.isdigit() else "N/A"
    if len(amenity_tags) >= 3:
        text = amenity_tags[2].get_text(strip=True)
        amenities["toilets"] = int(text) if text.isdigit() else "N/A"
    
    return amenities
    
# property image url
def extract_image_url(property_info):
    """
    Extracts the image URL from a property card.
    Returns the URL string if found, otherwise None.
    """
    img_tag = property_info.find("img")
    if img_tag and img_tag.get("src"):
        return img_tag["src"]
    return None


# Furnishing status detection 
def furnishing_status(property_info, img_url: str) -> str:
    """ First check image URL if not found then
        check description text"""
    if img_url:
        text = img_url.lower()
        if "semi-furnished" in text or "partially-furnished" in text:
            return "Partially Furnished"
        elif "furnished" in text:
            return "Furnished"
        elif "unfurnished" in text:
            return "Unfurnished"
    
    """ check description text"""
    desc_tag = property_info.find("div", class_="similar-listings-info")
    description = desc_tag.get_text(strip=True).lower() if desc_tag else ""
    
    if "semi-furnished" in description or "partially furnished" in description:
        return "Partially Furnished"
    elif "furnished" in description:
        return "Furnished"
    elif "unfurnished" in description:
        return "Unfurnished"
    
    return "Not Specified"

# property date
def normalize_date(raw_date: str) -> dict:
    """
    Normalize property date strings when both Updated and Added
    are in the same span.
    """
    raw_date = raw_date.lower()
    today = datetime.today()
    result = {"updated_date": None, "added_date": None}
    
    # Handle relative dates first
    if "updated today" in raw_date:
        result["updated_date"] = today.strftime("%Y-%m-%d")
    elif "updated yesterday" in raw_date:
        result["updated_date"] = (today - timedelta(days=1)).strftime("%Y-%m-%d")
    
    # Handle absolute dates (both updated and added in same string)
    parts = raw_date.split(",")
    for part in parts:
        part = part.strip()
        if part.startswith("updated"):
            date_str = part.replace("updated", "").strip()
            try:
                result["updated_date"] = datetime.strptime(date_str, "%d %b %Y").strftime("%Y-%m-%d")
            except:
                pass
        elif part.startswith("added"):
            date_str = part.replace("added", "").strip()
            try:
                result["added_date"] = datetime.strptime(date_str, "%d %b %Y").strftime("%Y-%m-%d")
            except:
                pass
    
    return result


# scrap all peoperties
def scrap_page_property(property_info):
    """
    scrap single page property to return list of dictionary
    """
    single_page_property= []
    
    for property_info in properties_info:
        property_title_div= property_info.find("div", class_= "similar-listings-info").find('h2')
        property_title= property_title_div.get_text() if property_title_div is not None else "N/A"

        listing_type_div= property_info.find("div", class_= "similar-listings-info").find('h3')
        listing_type = listing_type_div.get_text() if listing_type_div is not None else "N/A"
        
        property_type_div= property_info.find("div", class_= "similar-listings-info").find('h2')
        property_type = property_type_div.get_text() if property_type_div is not None else "N/A"
        
        property_price_div= property_info.find("div", class_= "similar-listings-price").find('h4')
        property_price= property_price_div.get_text()if property_price_div is not None else "N/A"  
        
        property_price_currency_div= property_info.find("div", class_= "similar-listings-price").find('span')
        property_price_currency= property_price_currency_div.get_text()if property_price_currency_div is not None else "N/A"  

        amenities = property_amenities(property_info)
         
        property_location_div= property_info.find("div", class_= "similar-listings-info").find('p')
        property_location= property_location_div.get_text()if property_location_div is not None else "N/A" 

        property_agent_name_div = property_info.find('div', class_="media").find('img')
        property_agent_name= property_agent_name_div.get('alt') if property_location_div is not None else "N/A"
        
        Property_agent_link_div= property_info.find('div', class_='similar-listing-contact').find('a')
        Property_agent_link= Property_agent_link_div.get('href') if Property_agent_link_div is not None else "N/A"
        
        property_date = property_info.find("div", class_= "media-body").find('h5')
        raw_date = property_date.get_text(strip=True) if property_date else ""
        dates = normalize_date(raw_date)

        img_url = extract_image_url(property_info)

        furnishing = furnishing_status(property_info, img_url)

        favorites_div = property_info.find('a', class_="listings-favorite")
        favorites = favorites_div.get('href') if favorites_div is not None else "N/A"

        
    
        single_property = {
            "title": property_title,
            "listing_type": listing_type,
            "property_type": property_type,
            "price": property_price,
            "currency": property_price_currency,
            "bedrooms": amenities["bedrooms"],
            "bathrooms": amenities["bathrooms"],
            "toilets": amenities["toilets"],
            "location": property_location,
            "agent_name": property_agent_name,
            "agent_link": Property_agent_link,
            "updated_date": dates["updated_date"],
            "added_date": dates["added_date"], 
            "image_url": img_url,
            "furnishing": furnishing,
            "favorite": favorites
        }
        single_page_property.append(single_property)
    
    return single_page_property

# %%
# all properties
all_property = {}

# all pages of website
for page_num in range(1,6):
    # website URL
    URL = f"https://privateproperty.ng/property-for-sale?page={page_num}"
    print(f"Scrapping property data from page {page_num}")

    # make connection
    soup_content = make_connection(URL)

    # single page property 
    properties_info = soup_content.find_all("div", class_="similar-listings-item" )

    single_page_property = scrap_page_property(properties_info)
    print(f"Property Scrapped successfully: {len(single_page_property)} properties Retrived")
    
    all_property.update({f"page {page_num}":single_page_property})
# Out:
# Scrapping property data from page 1
# Property Scrapped successfully: 22 properties Retrived
# Scrapping property data from page 2
# Property Scrapped successfully: 22 properties Retrived
# Scrapping property data from page 3
# Property Scrapped successfully: 22 properties Retrived
# Scrapping property data from page 4
# Property Scrapped successfully: 22 properties Retrived
# Scrapping property data from page 5
# Property Scrapped successfully: 22 properties Retrived

# %%
len(all_property)
# Out:
# 5

# %%
len(all_property["page 1"])
# Out:
# 22

# %%
all_property["page 1"]
# Out:
# [{'title': 'Lovely 4 Flats On About 2 Plots Of Land In Ogba Ikeja',
#   'listing_type': '3 BEDROOM BLOCK OF FLATS For Sale',
#   'property_type': 'Lovely 4 Flats On About 2 Plots Of Land In Ogba Ikeja',
#   'price': '₦ 195,000,000',
#   'currency': '₦',
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'toilets': 2,
#   'location': '\n\n\n Aguda Ogba Lagos',
#   'agent_name': 'Loyalty Property',
#   'agent_link': '/estate-agents/loyaltyhomeslimited',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48623960'},
#  {'title': '500sqm Residential Land Located In Abuja',
#   'listing_type': 'RESIDENTIAL LAND FOR SALE',
#   'property_type': '500sqm Residential Land Located In Abuja',
#   'price': '₦ 85,000,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Lokogoma Abuja Phase 3 Abuja',
#   'agent_name': 'Benjoy Properties',
#   'agent_link': '/estate-agents/benjoyproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '/assets/static/734fe629d8c13f356451f9462f658e79-comingsoon.jpg',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48641780'},
#  {'title': 'A Hotel With A Total Of 150 Rooms At Port Harcourt For Sale',
#   'listing_type': 'HOTEL FOR SALE',
#   'property_type': 'A Hotel With A Total Of 150 Rooms At Port Harcourt For Sale',
#   'price': '₦ 2,800,000,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Port Harcourt Aba Expressway Port Harcourt Rivers',
#   'agent_name': 'Benjoy Properties',
#   'agent_link': '/estate-agents/benjoyproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48642041'},
#  {'title': 'Affordable Commercial Plots @ Omole Ikeja',
#   'listing_type': 'MIXED USE LAND FOR SALE',
#   'property_type': 'Affordable Commercial Plots @ Omole Ikeja',
#   'price': '₦ 550,000,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Kosofe , Ayhomes Luxury Villa Ikeja Ikeja Lagos',
#   'agent_name': 'Dfhl Investment Ltd ',
#   'agent_link': '/estate-agents/dfhlinvestmentltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48641884'},
#  {'title': '5 Bedroom Duplex With Bq',
#   'listing_type': '5 BEDROOM DUPLEX FOR SALE',
#   'property_type': '5 Bedroom Duplex With Bq',
#   'price': '₦ 650,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Vgc /victoria Garden Castle/ajah Victoria Garden City Lekki Lagos',
#   'agent_name': 'Dfhl Investment Ltd ',
#   'agent_link': '/estate-agents/dfhlinvestmentltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48642099'},
#  {'title': '5 Bedroom Fully Detached Duplex With Swimming Pool, Cinema, Home Spa, Sauna, And Open Terrace',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': '5 Bedroom Fully Detached Duplex With Swimming Pool, Cinema, Home Spa, Sauna, And Open Terrace',
#   'price': '₦ 2,300,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Cowrie Creek, Ikate, Lekki Ikate Elegushi Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48631852'},
#  {'title': 'Newly Built Luxurious 2 Bedroom Apartment',
#   'listing_type': '2 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': 'Newly Built Luxurious 2 Bedroom Apartment',
#   'price': '₦ 165,000,000',
#   'currency': '₦',
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'toilets': 3,
#   'location': '\n\n\n Salem, Ikate Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48631855'},
#  {'title': 'Newly Built Luxurious 3 Bedroom Apartment With Bq',
#   'listing_type': '3 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': 'Newly Built Luxurious 3 Bedroom Apartment With Bq',
#   'price': '₦ 310,000,000',
#   'currency': '₦',
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'toilets': 4,
#   'location': '\n\n\n Ikate Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48631860'},
#  {'title': 'Newly Built Luxurious 2 Bedroom Apartment With Bq',
#   'listing_type': '2 BEDROOM FLAT & APARTMENT FOR SALE',
#   'property_type': 'Newly Built Luxurious 2 Bedroom Apartment With Bq',
#   'price': '₦ 200,000,000',
#   'currency': '₦',
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'toilets': 3,
#   'location': '\n\n\n Ikate Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48631864'},
#  {'title': 'Newly Built Luxurious 5 Bedroom Terrace Duplex',
#   'listing_type': '5 BEDROOM TERRACED DUPLEX FOR SALE',
#   'property_type': 'Newly Built Luxurious 5 Bedroom Terrace Duplex',
#   'price': '₦ 350,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Ikate Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48631911'},
#  {'title': 'Brand New 5 Bedroom Terrace Duplex',
#   'listing_type': '5 BEDROOM TERRACED DUPLEX For Sale',
#   'property_type': 'Brand New 5 Bedroom Terrace Duplex',
#   'price': '₦ 370,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 5,
#   'location': '\n\n\n Shonibare Estate Maryland Lagos',
#   'agent_name': 'Loyalty Property',
#   'agent_link': '/estate-agents/loyaltyhomeslimited',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48626776'},
#  {'title': 'Newly Built Luxurious 5 Bedroom Fully Detached Duplex With Bq',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built Luxurious 5 Bedroom Fully Detached Duplex With Bq',
#   'price': '₦ 520,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 5,
#   'location': '\n\n\n Chevron Drive Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48634551'},
#  {'title': 'Newly Built Luxurious 6 Bedroom Fully Detached Smart Duplex',
#   'listing_type': '6 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built Luxurious 6 Bedroom Fully Detached Smart Duplex',
#   'price': '₦ 750,000,000',
#   'currency': '₦',
#   'bedrooms': 6,
#   'bathrooms': 6,
#   'toilets': 6,
#   'location': '\n\n\n Chevron Drive Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48634554'},
#  {'title': 'Newly Built 5 Bedroom Fully Detached Smart Duplex With Bq',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built 5 Bedroom Fully Detached Smart Duplex With Bq',
#   'price': '₦ 360,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Chevron Drive Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48634640'},
#  {'title': 'Newly Built 5 Bedroom Fully Detached Smart Duplex',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built 5 Bedroom Fully Detached Smart Duplex',
#   'price': '₦ 360,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 5,
#   'location': '\n\n\n Chevron Drive Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48634717'},
#  {'title': '4 Bedroom Luxurious Apartment With Bq',
#   'listing_type': '4 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': '4 Bedroom Luxurious Apartment With Bq',
#   'price': '₦ 400,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n Victoria Island Victoria Island Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48635670'},
#  {'title': 'Newly Built 5 Bedroom Fully Detached Duplex',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built 5 Bedroom Fully Detached Duplex',
#   'price': '₦ 2,300,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 5,
#   'location': '\n\n\n Ikoyi Ikoyi Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48636845'},
#  {'title': 'Furnished 2 Bedroom Apartment With Bq',
#   'listing_type': '2 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': 'Furnished 2 Bedroom Apartment With Bq',
#   'price': '₦ 180,000,000',
#   'currency': '₦',
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'toilets': 2,
#   'location': '\n\n\n Ilasan Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Furnished',
#   'favorite': '/profile/add-favorite/48638426'},
#  {'title': '3 Bedroom Apartments Available',
#   'listing_type': '3 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': '3 Bedroom Apartments Available',
#   'price': '₦ 350,000,000',
#   'currency': '₦',
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'toilets': 3,
#   'location': '\n\n\n Lekki Phase 1 Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48639400'},
#  {'title': '3 Bedroom Apartments With Bq',
#   'listing_type': '3 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': '3 Bedroom Apartments With Bq',
#   'price': '₦ 380,000,000',
#   'currency': '₦',
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'toilets': 3,
#   'location': '\n\n\n Lekki Phase 1 Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48639717'},
#  {'title': '2 Bedroom Apartment',
#   'listing_type': '2 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': '2 Bedroom Apartment',
#   'price': '₦ 300,000,000',
#   'currency': '₦',
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'toilets': 2,
#   'location': '\n\n\n Lekki Phase 1 Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48639719'},
#  {'title': '5 Bedroom Luxury Detached Duplexes With Bq',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': '5 Bedroom Luxury Detached Duplexes With Bq',
#   'price': '₦ 450,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 5,
#   'location': '\n\n\n Chevron Drive Lekki Lagos',
#   'agent_name': 'Martin Doks Homes Ltd',
#   'agent_link': '/estate-agents/martindokshomesltd',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48640366'}]

# %% [markdown]
# /*Attributes:
#
# -property title = property_info.find("div", class_= "similar-listings-info").find('h2').get_text()
# -listing type = property_info.find("div", class_= "similar-listings-info").find('h3').get_text()
# -property price = property_info.find("div", class_= "similar-listings-price").find('h4').get_text()
# -property price currency = property_info.find("div", class_= "similar-listings-price").find('span').get_text()
# -property location = property_info.find("div", class_= "similar-listings-info").find('p').get_text()
# -Property agent link = property_info.find('div', class_='similar-listing-contact').find('a').get('href')
# -property date = property_info.find("div", class_= "media-body").find('h5').get_text() */

# %%
single_page_property
# Out:
# [{'title': 'Fairmont Green & Smart Estate',
#   'listing_type': 'RESIDENTIAL LAND For Sale',
#   'property_type': 'Fairmont Green & Smart Estate',
#   'price': '₦ 30,000,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n With Cofo Ibeju Lekki Lagos',
#   'agent_name': 'Andy Moore Properties',
#   'agent_link': '/estate-agents/andymooreproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/41758309'},
#  {'title': 'Luxury 4bedroom Semi Detached',
#   'listing_type': '4 BEDROOM SEMI DETACHED DUPLEX FOR SALE',
#   'property_type': 'Luxury 4bedroom Semi Detached',
#   'price': '₦ 150,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n Lekki Plamcity Ado Ajah Lagos',
#   'agent_name': 'DAYO OKENIYI & CO',
#   'agent_link': '/estate-agents/dayookeniyico',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48640549'},
#  {'title': 'Newly Built 4 Bedroom Terrace Duplex',
#   'listing_type': '4 BEDROOM TERRACED DUPLEX FOR SALE',
#   'property_type': 'Newly Built 4 Bedroom Terrace Duplex',
#   'price': '₦ 115,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n Orchid Lekki Lagos',
#   'agent_name': 'Bluehedge Realtors ',
#   'agent_link': '/estate-agents/bluehedgerealtorsestate',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/30858949'},
#  {'title': 'Newly Built 2 Bed Apartment With Elevator',
#   'listing_type': '2 BEDROOM BLOCK OF FLATS FOR SALE',
#   'property_type': 'Newly Built 2 Bed Apartment With Elevator',
#   'price': '₦ 305,000,000',
#   'currency': '₦',
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'toilets': 3,
#   'location': '\n\n\n Lekki Phase1 Lekki Phase 1 Lekki Lagos',
#   'agent_name': 'Alvinacle properties ',
#   'agent_link': '/estate-agents/alvinacleproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48389553'},
#  {'title': 'Lovely 5 Bed Duplex With 1 Study In An Estate',
#   'listing_type': '5 BEDROOM SEMI DETACHED DUPLEX FOR SALE',
#   'property_type': 'Lovely 5 Bed Duplex With 1 Study In An Estate',
#   'price': '₦ 500,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Lekki Right Lekki Phase 1 Lekki Lagos',
#   'agent_name': 'Alvinacle properties ',
#   'agent_link': '/estate-agents/alvinacleproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48391514'},
#  {'title': 'Luxury 3 Bedroom Apartment +bq+pool+ Elevator Etc',
#   'listing_type': '3 BEDROOM FLAT & APARTMENT FOR SALE',
#   'property_type': 'Luxury 3 Bedroom Apartment +bq+pool+ Elevator Etc',
#   'price': '₦ 900,000,000',
#   'currency': '₦',
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'toilets': 4,
#   'location': '\n\n\n Banana Island Estate Banana Island Ikoyi Lagos',
#   'agent_name': 'PRINCE ADEMOLA OSINUGA INTERNATIONAL ',
#   'agent_link': '/estate-agents/princeademolaosinugainternational',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48626271'},
#  {'title': 'Lovely 5 Bed Smart House In A Gated Estate',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Lovely 5 Bed Smart House In A Gated Estate',
#   'price': '₦ 550,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Megamound Estate Ikota Lekki Lagos',
#   'agent_name': 'Alvinacle properties ',
#   'agent_link': '/estate-agents/alvinacleproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48637743'},
#  {'title': 'Newly Built 5 Bedroom Detached House +bq+pool',
#   'listing_type': '5 BEDROOM DUPLEX FOR SALE',
#   'property_type': 'Newly Built 5 Bedroom Detached House +bq+pool',
#   'price': '₦ 3,000,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Banana Island Estate Banana Island Ikoyi Lagos',
#   'agent_name': 'PRINCE ADEMOLA OSINUGA INTERNATIONAL ',
#   'agent_link': '/estate-agents/princeademolaosinugainternational',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/35814730'},
#  {'title': 'Dolphin Estate (solar Powered Estate In Enugu).',
#   'listing_type': 'RESIDENTIAL LAND FOR SALE',
#   'property_type': 'Dolphin Estate (solar Powered Estate In Enugu).',
#   'price': '₦ 25,000,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Coal City Alliance, New Enugu Independence Layout Estate Phase 2. Enugu Area Enugu',
#   'agent_name': 'homeway limited ',
#   'agent_link': '/estate-agents/homewaylimited',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48642762'},
#  {'title': 'Newly Built 4 Bed Duplex With 1bq',
#   'listing_type': '4 BEDROOM DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built 4 Bed Duplex With 1bq',
#   'price': '₦ 400,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n New Road Lekki Expressway Lekki Lagos',
#   'agent_name': 'Alvinacle properties ',
#   'agent_link': '/estate-agents/alvinacleproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48621942'},
#  {'title': 'Massive 5 Bedroom Detached Duplex With Swimming Pool',
#   'listing_type': '5 BEDROOM DETACHED DUPLEX For Sale',
#   'property_type': 'Massive 5 Bedroom Detached Duplex With Swimming Pool',
#   'price': '₦ 1,100,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Katampe Ext. Abuja Phase 2',
#   'agent_name': 'Innerworkings Investment Limited',
#   'agent_link': '/estate-agents/innerworkings',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48628011'},
#  {'title': 'Land For Sale At A Promo For Independence',
#   'listing_type': 'RESIDENTIAL LAND FOR SALE',
#   'property_type': 'Land For Sale At A Promo For Independence',
#   'price': '₦ 8,500,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Oxford Heights Estate Awoyaya Ajah Lagos',
#   'agent_name': 'Timabestproperties',
#   'agent_link': '/estate-agents/timabestproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48630979'},
#  {'title': 'Luxury 4 Bedroom Semi Detached House + Bq',
#   'listing_type': '4 BEDROOM TERRACE FOR SALE',
#   'property_type': 'Luxury 4 Bedroom Semi Detached House + Bq',
#   'price': '₦ 1,199,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n Ikoyi Ikoyi Lagos',
#   'agent_name': 'PRINCE ADEMOLA OSINUGA INTERNATIONAL ',
#   'agent_link': '/estate-agents/princeademolaosinugainternational',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48642272'},
#  {'title': 'Land For Sale',
#   'listing_type': 'RESIDENTIAL LAND FOR SALE',
#   'property_type': 'Land For Sale',
#   'price': '₦ 4,500,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n City Nest Phase 6 Ibefun Leguru Odogbolu Ogun',
#   'agent_name': 'Timabestproperties',
#   'agent_link': '/estate-agents/timabestproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48626819'},
#  {'title': 'Luxury Farm Estate',
#   'listing_type': 'COMMERCIAL LAND FOR SALE',
#   'property_type': 'Luxury Farm Estate',
#   'price': '₦ 2,700,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Aroko Farm And Resort Ibadan Ibadan Oyo',
#   'agent_name': 'Timabestproperties',
#   'agent_link': '/estate-agents/timabestproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48627072'},
#  {'title': 'Newly Built 4 Bedroom Semi Detached Duplex',
#   'listing_type': '4 BEDROOM SEMI DETACHED DUPLEX FOR SALE',
#   'property_type': 'Newly Built 4 Bedroom Semi Detached Duplex',
#   'price': '₦ 150,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n Chevron Tollgate Lekki Lagos',
#   'agent_name': 'Bluehedge Realtors ',
#   'agent_link': '/estate-agents/bluehedgerealtorsestate',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/30851628'},
#  {'title': 'For Sale Luxury 5 Bedroom Semi Detached House + Bq Etc In Banana Island',
#   'listing_type': '5 BEDROOM HOUSE FOR SALE',
#   'property_type': 'For Sale Luxury 5 Bedroom Semi Detached House + Bq Etc In Banana Island',
#   'price': '₦ 2,400,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Banana Island Banana Island Ikoyi Lagos',
#   'agent_name': 'PRINCE ADEMOLA OSINUGA INTERNATIONAL ',
#   'agent_link': '/estate-agents/princeademolaosinugainternational',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/45435329'},
#  {'title': '3 Bedroom Apartment + Bq',
#   'listing_type': '3 BEDROOM FLAT & APARTMENT FOR SALE',
#   'property_type': '3 Bedroom Apartment + Bq',
#   'price': '₦ 750,000,000',
#   'currency': '₦',
#   'bedrooms': 3,
#   'bathrooms': 3,
#   'toilets': 4,
#   'location': '\n\n\n Banana Island Banana Island Ikoyi Lagos',
#   'agent_name': 'PRINCE ADEMOLA OSINUGA INTERNATIONAL ',
#   'agent_link': '/estate-agents/princeademolaosinugainternational',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48285896'},
#  {'title': 'New 5 Bedroom Terrace House +2bq+pool Etc',
#   'listing_type': '5 BEDROOM TERRACE FOR SALE',
#   'property_type': 'New 5 Bedroom Terrace House +2bq+pool Etc',
#   'price': '₦ 2,250,000,000',
#   'currency': '₦',
#   'bedrooms': 5,
#   'bathrooms': 5,
#   'toilets': 6,
#   'location': '\n\n\n Banana Island Estate Banana Island Ikoyi Lagos',
#   'agent_name': 'PRINCE ADEMOLA OSINUGA INTERNATIONAL ',
#   'agent_link': '/estate-agents/princeademolaosinugainternational',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/35393387'},
#  {'title': 'Luxury 3 Bed Apartments +bq In Eko Atlantic (phoenix Tower).',
#   'listing_type': '2 BEDROOM TERRACED DUPLEX FOR SALE',
#   'property_type': 'Luxury 3 Bed Apartments +bq In Eko Atlantic (phoenix Tower).',
#   'price': '₦ 846,279,000',
#   'currency': '₦',
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'toilets': 3,
#   'location': '\n\n\n Eko Pearl Towers, Kuramo Waters, Ocean Front District. Eko Atlantic Victoria Island Lagos',
#   'agent_name': 'homeway limited ',
#   'agent_link': '/estate-agents/homewaylimited',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/36979293'},
#  {'title': 'Exquisite, Brand New 4 Bedroom Semi Detached Duplex',
#   'listing_type': '4 BEDROOM SEMI DETACHED DUPLEX FOR SALE',
#   'property_type': 'Exquisite, Brand New 4 Bedroom Semi Detached Duplex',
#   'price': '₦ 150,000,000',
#   'currency': '₦',
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'toilets': 5,
#   'location': '\n\n\n Ikota Ikota Lekki Lagos',
#   'agent_name': 'Bluehedge Realtors ',
#   'agent_link': '/estate-agents/bluehedgerealtorsestate',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/48642194'},
#  {'title': 'Premium Land For Sale',
#   'listing_type': 'MIXED USE LAND FOR SALE',
#   'property_type': 'Premium Land For Sale',
#   'price': '₦ 30,000,000',
#   'currency': '₦',
#   'bedrooms': 'N/A',
#   'bathrooms': 'N/A',
#   'toilets': 'N/A',
#   'location': '\n\n\n Lekki Epe Expressway Ikegun Ibeju Lekki Lagos',
#   'agent_name': 'Timabestproperties',
#   'agent_link': '/estate-agents/timabestproperties',
#   'updated_date': '2025-11-27',
#   'added_date': None,
#   'image_url': '...',
#   'furnishing': 'Not Specified',
#   'favorite': '/profile/add-favorite/41301550'}]

# %% [markdown]
# # Property for Sale

# %%
# Importing Libraries

import requests
from bs4 import BeautifulSoup 
import re

# importing the library to scrap image
import os
from urllib.parse import urljoin

# %%
# Error handling function while loading the site and
# Defining the Header for using User-Agent approach to have access to the site info

URL ="https://privateproperty.ng/property-for-sale"

HEADER = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36"
}

def make_connection_now(url):
    try:
        response = requests.get(url, headers=HEADER)
        if response.status_code == 200:
            soup_contents = BeautifulSoup(response.content, 'html.parser')
            return soup_contents
        else:
            print(f"Resources Not available! Status Code {response.status_code}")
    except Exception as e:
        print(f"An Error occurs. Message: {e}")


def scrap_page_property(properties_info_div):
    """
    scrap single page property to return list of dictionary
    """
    single_page_div_property= []
    
    for property_info_div in properties_info_div:
        property_title_div= property_info_div.find("div", class_= "similar-listings-info").find('h2')
        property_title= property_title_div.get_text() if property_title_div is not None else "N/A"
        
        listing_type_div= property_info_div.find("div", class_= "similar-listings-info").find('h3')
        listing_type = listing_type_div.get_text() if listing_type_div is not None else "N/A"
        
        property_price_div= property_info_div.find("div", class_= "similar-listings-price").find('h4')
        property_price= property_price_div.get_text()if property_price_div is not None else "N/A"  
        
        property_price_currency_div= property_info_div.find("div", class_= "similar-listings-price").find('span')
        property_price_currency= property_price_currency_div.get_text()if property_price_currency_div is not None else "N/A"        
         
        property_location_div= property_info_div.find("div", class_= "similar-listings-info").find('p')
        property_location= property_location_div.get_text()if property_location_div is not None else "N/A" 
        
        Property_agent_link_div= property_info_div.find('div', class_='similar-listing-contact').find('a')
        Property_agent_link= Property_agent_link_div.get('href') if Property_agent_link_div is not None else "N/A"
        
        property_date_div= property_info_div.find("div", class_= "media-body").find('h5')
        property_date= property_date_div.get_text()if property_date_div is not None else "N/A"
        
    
        single_property = {
            "title": property_title,
            "type": listing_type,
            "price": property_price,
            "currency": property_price_currency,                  
            "location": property_location,
            "link": Property_agent_link,
            "date": property_date     
        }
        single_page_div_property.append(single_property)
    
    return single_page_div_property

# %%
scrap_page_property(properties_info_div)

# %%
contents = make_connection_now(url = URL)
contents

# %%
property_info_div = contents.find('div', class_="similar-listings-item")

# %%
propt = contents.find("div", class_="similar-listings-image gold")
propt

# %%
property_info_div

# %% [markdown]
# /*Attributes:
#
# -property title = property_info_div.find("div", class_= "similar-listings-info").find('h2').get_text()
# -listing type = property_info_div.find("div", class_= "similar-listings-info").find('h3').get_text()
# -property price = property_info_div.find("div", class_= "similar-listings-price").find('h4').get_text()
# -property price currency = property_info_div.find("div", class_= "similar-listings-price").find('span').get_text()
# -property location = property_info_div.find("div", class_= "similar-listings-info").find('p').get_text()
# -Property agent link = property_info_div.find('div', class_='similar-listing-contact').find('a').get('href')
# -property date = property_info_div.find("div", class_= "media-body").find('h5').get_text() */

# %%
# single page property with 22 properties
properties_info_div = contents.find_all("div", class_="similar-listings-item" )
properties_info_div

# %%
single_page_div_property= []

for property_info_div in properties_info_div:
    property_title= property_info_div.find("div", class_= "similar-listings-info").find('h2').get_text()
    listing_type= property_info_div.find("div", class_= "similar-listings-info").find('h3').get_text()
    property_price= property_info_div.find("div", class_= "similar-listings-price").find('h4').get_text()
    property_price_currency= property_info_div.find("div", class_= "similar-listings-price").find('span').get_text()
    property_location=property_info_div.find("div", class_= "similar-listings-info").find('p').get_text()
    Property_agent_link= property_info_div.find('div', class_='similar-listing-contact').find('a').get('href')
    property_date= property_info_div.find("div", class_= "media-body").find('h5').get_text()
    
    single_property = {
        "title": property_title,
        "type": listing_type,
        "price": property_price,
        "currency": property_price_currency,
        "location": property_location,
        "link": Property_agent_link,
        "date": property_date,
    }
    single_page_div_property.append(single_property)

# %%
single_page_div_property

# %%
# property amenity
def property_amenities(property_info_div):
    amenities = {"bedrooms": "N/A", "bathrooms": "N/A", "toilets": "N/A"}
    
    amenity_div = property_info_div.find("ul", class_="property-benefit")
    if not amenity_div:
        return amenities
    
    amenity_tags = amenity_div.find_all("li")
    
    # Use index positions
    if len(amenity_tags) >= 1:
        text = amenity_tags[0].get_text(strip=True)
        amenities["bedrooms"] = int(text) if text.isdigit() else "N/A"
    if len(amenity_tags) >= 2:
        text = amenity_tags[1].get_text(strip=True)
        amenities["bathrooms"] = int(text) if text.isdigit() else "N/A"
    if len(amenity_tags) >= 3:
        text = amenity_tags[2].get_text(strip=True)
        amenities["toilets"] = int(text) if text.isdigit() else "N/A"
    
    return amenities

# %%
property_amenities(property_info_div)

# %%
# property image url
def property_image_url(property_info_div):
    
    img_tag = property_info.find("img")
    if img_tag and img_tag.get("src"):
        return img_tag["src"]
    return None

# %%
property_image_url(property_info_div)

# %%
# furnishing status is in the image url therefore extracting it from url
img_tag = property_info_div.find('img')
img_url = img_tag.get('data-src') or img_tag.get('data-original') or img_tag.get('src')

def furnishing_status_from_url(img_url: str) -> str:
    if not img_url:
        return "Not Specified"
    
    text = img_url.lower()
    
    if "semi-furnished" in text or "partially-furnished" in text:
        return "Partially Furnished"
    elif "furnished" in text:
        return "Furnished"
    elif "unfurnished" in text:
        return "Unfurnished"
    else:
        return "Not Specified"

# %%
furnishing_status_from_url(img_url)
