# %% [markdown]
# # Data Extraction from Nigeria Property Center website

# %%
import requests
from bs4 import BeautifulSoup

# %%
requests.get ("https://nigeriapropertycentre.com/for-sale")
# Out:
# <Response [200]>

# %%
response = requests.get("https://nigeriapropertycentre.com/for-sale")

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta charset="utf-8">\n\n        <meta name="apple-itunes-app" content="app-id=1125813120">\n    <meta name="google-play-app" content="app-id=com.nigeriapropertycentre.app">\n    \n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="csrf-token" content="vj4wjLt5QvsZZircMg7O6NuhutJXspAJFeh89rE9">\n\n    <meta name="robots" content="max-image-preview:large">\n\n    <link rel="manifest" href="https://st.nigeriapropertycentre.com/webapp/manifest.json">\n    <link rel="apple-touch-icon" href="https://assets.nigeriapropertycentre.com/2fdb50a6-e85a-48b8-ae43-e29134e3be24/launcher-icon-60.png">\n    <link rel="apple-touch-icon" sizes="76x76" href="https://assets.nigeriapropertycentre.com/2fdb50a6-e85a-48b8-ae43-e29134e3be24/launcher-icon-76.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="https://assets.nigeriapropertycentre.com/2fdb50a6-e85a-48b8-ae43-e29134e3be24/launcher-icon-120.png">
# ...

# %%
URL = "https://nigeriapropertycentre.com/for-sale"

def make_connection(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup_content = BeautifulSoup (response.content, "html.parser")
            return soup_content
        else:
            print (f"Resources Not Available! Status Code {response.status_code}") 
    except Exception as e:
                print (f"An Error occurs. Message: {e}")

# %%
content = make_connection(url=URL)

# %%
content
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="app-id=1125813120" name="apple-itunes-app"/>
# <meta content="app-id=com.nigeriapropertycentre.app" name="google-play-app"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="4Xb9QOohljxQkzvYPdcGFl1vxncFSVRo4ClJLgLu" name="csrf-token"/>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://st.nigeriapropertycentre.com/webapp/manifest.json" rel="manifest"/>
# <link href="https://assets.nigeriapropertycentre.com/2fdb50a6-e85a-48b8-ae43-e29134e3be24/launcher-icon-60.png" rel="apple-touch-icon"/>
# <link href="https://assets.nigeriapropertycentre.com/2fdb50a6-e85a-48b8-ae43-e29134e3be24/launcher-icon-76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://assets.nigeriapropertycentre.com/2fdb50a6-e85a-48b8-ae43-e29134e3be24/launcher-icon-120.png" rel="apple-touch-icon" sizes="120x120"/>
# ...
